# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 下載檔案

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# /1913edc))\\n\\n### [`v1.10.18`](https://togithub.com/jessestuart/docker-hub-utils/releases/v1.10.18)\\n\\n[Compare Source](https://togithub.com/jessestuart/docker-hub-utils/compare/v1.10.17...v1.10.18)\\n\\n##### Bug Fixes\\n\\n-   **deps:** update dependency luxon to v1.21.3 ([7ac911f](https://togithub.com/jessestuart/docker-hub-utils/commit/7ac911f))\\n\\n### [`v1.10.17`](https://togithub.com/jessestuart/docker-hub-utils/releases/v1.10.17)\\n\\n[Compare Source](https://togithub.com/jessestuart/docker-hub-utils/compare/v1.10.16...v1.10.17)\\n\\n##### Bug Fixes\\n\\n-   **deps:** update dependency pino to v5.14.0 ([a760d1f](https://togithub.com/jessestuart/docker-hub-utils/commit/a760d1f))\\n\\n### [`v1.10.16`](https://togithub.com/jessestuart/docker-hub-utils/releases/v1.10.16)\\n\\n[Compare Source](https://togithub.com/jessestuart/docker-hub-utils/compare/v1.10.15...v1.10.16)\\n\\n##### Bug Fixes\\n\\n-   **deps:** update dependency luxon to v1.21.2 ([f2b0257](https://togithub.com/jessestuart/docker-hub-utils/commit/f2b0257))\\n\\n</details>\\n\\n---\\n\\n### Renovate configuration\\n\\n:date: **Schedule**: At any time (no schedule defined).\\n\\n:vertical_traffic_light: **Automerge**: Enabled.\\n\\n:recycle: **Rebasing**: Whenever PR is stale, or if you modify the PR title to begin with \\"`rebase!`\\".\\n\\n:no_bell: **Ignore**: Close this PR and you won\'t be reminded about this update again.\\n\\n---\\n\\n - [ ] <!-- rebase-check -->If you want to rebase/retry this PR, check this box\\n\\n---\\n\\nNewsflash: Renovate has joined WhiteSource, and is now free for all use. [Learn more](https://renovate.whitesourcesoftware.com/blog/renovate-is-now-part-of-whitesource/) or view updated [terms](https://renovate.whitesourcesoftware.com/terms-of-service/) and [privacy](https://renovate.whitesourcesoftware.com/privacy-policy/) policies.","created_at":"2019-11-19T01:47:47Z","updated_at":"2019-12-14T12:56:29Z","closed_at":"2019-12-14T12:56:29Z","merged_at":null,"merge_commit_sha":"de77ed005719027573b93feb5cb81c9c17eb3639","assignee":null,"assignees":[],"requested_reviewers":[],"requested_teams":[],"labels":[{"id":1537780175,"node_id":"MDU6TGFiZWwxNTM3NzgwMTc1","url":"https://api.github.com/repos/jessestuart/docker-hub-graphql-api/labels/renovate","name":"renovate","color":"ededed","default":false,"description":null}],"milestone":null,"commits_url":"https://api.github.com/repos/jessestuart/docker-hub-graphql-api/pulls/16/commits","review_comments_url":"https://api.github.com/repos/jessestuart/docker-hub-graphql-api/pulls/16/comments","review_comment_url":"https://api.github.com/repos/jessestuart/docker-hub-graphql-api/pulls/comments{/number}","comments_url":"https://api.github.com/repos/jessestuart/docker-hub-graphql-api/issues/16/comments","statuses_url":"https://api.github.com/repos/jessestuart/docker-hub-graphql-api/statuses/6b57c47d73ef1ab609520d44d43625ccb9dc5e7b","head":{"label":"jessestuart:renovate/docker-hub-utils-1.x","ref":"renovate/docker-hub-utils-1.x","sha":"6b57c47d73ef1ab609520d44d43625ccb9dc5e7b","user":{"login":"jessestuart","id":583147,"node_id":"MDQ6VXNlcjU4MzE0Nw==","avatar_url":"https://avatars2.githubusercontent.com/u/583147?v=4","gravatar_id":"","url":"https://api.github.com/users/jessestuart","html_url":"https://github.com/jessestuart","followers_url":"https://api.github.com/users/jessestuart/followers","following_url":"https://api.github.com/users/jessestuart/following{/other_user}","gists_url":"https://api.github.com/users/jessestuart/gists{/gist_id}","starred_url":"https://api.github.com/users/jessestuart/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/jessestuart/subscriptions","organizations_url":"https://api.github.com/users/jessestuart/orgs","repos_url":"https://api.github.com/users/jessestuart/repos","events_url":"https://api.github.com/users/jessestuart/events{/privacy}","received_events_url":"https://api.github.com/users/jessestuart/received_events","type":"User","site_adm ...

# %%
import json

json.loads(r.text)
# Out:
# iption': None}],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/pulls/16/commits',
#     'review_comments_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/pulls/16/comments',
#     'review_comment_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/issues/16/comments',
#     'statuses_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/statuses/6b57c47d73ef1ab609520d44d43625ccb9dc5e7b',
#     'head': {'label': 'jessestuart:renovate/docker-hub-utils-1.x',
#      'ref': 'renovate/docker-hub-utils-1.x',
#      'sha': '6b57c47d73ef1ab609520d44d43625ccb9dc5e7b',
#      'user': {'login': 'jessestuart',
#       'id': 583147,
#       'node_id': 'MDQ6VXNlcjU4MzE0Nw==',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/583147?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/jessestuart',
#       'html_url': 'https://github.com/jessestuart',
#       'followers_url': 'https://api.github.com/users/jessestuart/followers',
#       'following_url': 'https://api.github.com/users/jessestuart/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/jessestuart/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/jessestuart/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/jessestuart/subscriptions',
#       'organizations_url': 'https://api.github.com/users/jessestuart/orgs',
#       'repos_url': 'https://api.github.com/users/jessestuart/repos',
#       'events_url': 'https://api.github.com/users/jessestuart/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/jessestuart/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 198435058,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxOTg0MzUwNTg=',
#       'name': 'docker-hub-graphql-api',
#       'full_name': 'jessestuart/docker-hub-graphql-api',
#       'private': False,
#       'owner': {'login': 'jessestuart',
#        'id': 583147,
#        'node_id': 'MDQ6VXNlcjU4MzE0Nw==',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/583147?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/jessestuart',
#        'html_url': 'https://github.com/jessestuart',
#        'followers_url': 'https://api.github.com/users/jessestuart/followers',
#        'following_url': 'https://api.github.com/users/jessestuart/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/jessestuart/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/jessestuart/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/jessestuart/subscriptions',
#        'organizations_url': 'https://api.github.com/users/jessestuart/orgs',
#        'repos_url': 'https://api.github.com/users/jessestuart/repos',
#        'events_url': 'https://api.github.com/users/jessestuart/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/jessestuart/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/jessestuart/docker-hub-graphql-api',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api',
#       'forks_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/forks',
#       'keys_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/teams',
#       'hooks_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/hooks',
#       'issue_events_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/events',
#       'assignees_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/tags',
#       'blobs_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/languages',
#       'stargazers_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/stargazers',
#       'contributors_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/contributors',
#       'subscribers_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/subscribers',
#       'subscription_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/subscription',
#       'commits_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/merges',
#       'archive_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/downloads',
#       'issues_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/deployments',
#       'created_at': '2019-07-23T13:21:24Z',
#       'updated_at': '2019-12-14T12:53:42Z',
#       'pushed_at': '2019-12-14T12:55:50Z',
#       'git_url': 'git://github.com/jessestuart/docker-hub-graphql-api.git',
#       'ssh_url': 'git@github.com:jessestuart/docker-hub-graphql-api.git',
#       'clone_url': 'https://github.com/jessestuart/docker-hub-graphql-api.git',
#       'svn_url': 'https://github.com/jessestuart/docker-hub-graphql-api',
#       'homepage': 'https://dh.jesses.dev/api/',
#       'size': 1371,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': None,
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'jessestuart:master',
#      'ref': 'master',
#      'sha': 'df3f69dd361d88589b6037dd6c4df5394ac95618',
#      'user': {'login': 'jessestuart',
#       'id': 583147,
#       'node_id': 'MDQ6VXNlcjU4MzE0Nw==',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/583147?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/jessestuart',
#       'html_url': 'https://github.com/jessestuart',
#       'followers_url': 'https://api.github.com/users/jessestuart/followers',
#       'following_url': 'https://api.github.com/users/jessestuart/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/jessestuart/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/jessestuart/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/jessestuart/subscriptions',
#       'organizations_url': 'https://api.github.com/users/jessestuart/orgs',
#       'repos_url': 'https://api.github.com/users/jessestuart/repos',
#       'events_url': 'https://api.github.com/users/jessestuart/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/jessestuart/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 198435058,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxOTg0MzUwNTg=',
#       'name': 'docker-hub-graphql-api',
#       'full_name': 'jessestuart/docker-hub-graphql-api',
#       'private': False,
#       'owner': {'login': 'jessestuart',
#        'id': 583147,
#        'node_id': 'MDQ6VXNlcjU4MzE0Nw==',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/583147?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/jessestuart',
#        'html_url': 'https://github.com/jessestuart',
#        'followers_url': 'https://api.github.com/users/jessestuart/followers',
#        'following_url': 'https://api.github.com/users/jessestuart/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/jessestuart/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/jessestuart/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/jessestuart/subscriptions',
#        'organizations_url': 'https://api.github.com/users/jessestuart/orgs',
#        'repos_url': 'https://api.github.com/users/jessestuart/repos',
#        'events_url': 'https://api.github.com/users/jessestuart/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/jessestuart/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/jessestuart/docker-hub-graphql-api',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api',
#       'forks_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/forks',
#       'keys_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/teams',
#       'hooks_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/hooks',
#       'issue_events_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/events',
#       'assignees_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/tags',
#       'blobs_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/languages',
#       'stargazers_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/stargazers',
#       'contributors_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/contributors',
#       'subscribers_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/subscribers',
#       'subscription_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/subscription',
#       'commits_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/merges',
#       'archive_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/downloads',
#       'issues_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/deployments',
#       'created_at': '2019-07-23T13:21:24Z',
#       'updated_at': '2019-12-14T12:53:42Z',
#       'pushed_at': '2019-12-14T12:55:50Z',
#       'git_url': 'git://github.com/jessestuart/docker-hub-graphql-api.git',
#       'ssh_url': 'git@github.com:jessestuart/docker-hub-graphql-api.git',
#       'clone_url': 'https://github.com/jessestuart/docker-hub-graphql-api.git',
#       'svn_url': 'https://github.com/jessestuart/docker-hub-graphql-api',
#       'homepage': 'https://dh.jesses.dev/api/',
#       'size': 1371,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': None,
#       'forks': 0,
#       'open_issues': 2,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/pulls/16'},
#      'html': {'href': 'https://github.com/jessestuart/docker-hub-graphql-api/pull/16'},
#      'issue': {'href': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/issues/16'},
#      'comments': {'href': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/issues/16/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/pulls/16/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/pulls/16/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/jessestuart/docker-hub-graphql-api/statuses/6b57c47d73ef1ab609520d44d43625ccb9dc5e7b'}},
#     'author_association': 'CONTRIBUTOR',
#     'merged': False,
#     'mergeable': True,
#     'rebaseable': True,
#     'mergeable_state': 'unstable',
#     'merged_by': None,
#     'comments': 1,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 24,
#     'deletions': 7,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2019-12-14T12:56:30Z'},
#  {'id': '11088662856',
#   'type': 'IssuesEvent',
#   'actor': {'id': 16661034,
#    'login': 'TommiGustafsson-HMP',
#    'display_login': 'TommiGustafsson-HMP',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/TommiGustafsson-HMP',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16661034?'},
#   'repo': {'id': 197750172,
#    'name': 'hyvanmielenpelit/GnollHack',
#    'url': 'https://api.github.com/repos/hyvanmielenpelit/GnollHack'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/hyvanmielenpelit/GnollHack/issues/462',
#     'repository_url': 'https://api.github.com/repos/hyvanmielenpelit/GnollHack',
#     'labels_url': 'https://api.github.com/repos/hyvanmielenpelit/GnollHack/issues/462/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/hyvanmielenpelit/GnollHack/issues/462/comments',
#     'events_url': 'https://api.github.com/repos/hyvanmielenpelit/GnollHack/issues/462/events',
#     'html_url': 'https://github.com/hyvanmielenpelit/GnollHack/issues/462',
#     'id': 537910520,
#     'node_id': 'MDU6SXNzdWU1Mzc5MTA1MjA=',
#     'number': 462,
#     'title': 'Knight could have more STR and CON and less WIS',
#     'user': {'login': 'TommiGustafsson-HMP',
#      'id': 16661034,
#      'node_id': 'MDQ6VXNlcjE2NjYxMDM0',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/16661034?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/TommiGustafsson-HMP',
#      'html_url': 'https://github.com/TommiGustafsson-HMP',
#      'followers_url': 'https://api.github.com/users/TommiGustafsson-HMP/followers',
#      'following_url': 'https://api.github.com/users/TommiGustafsson-HMP/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/TommiGustafsson-HMP/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/TommiGustafsson-HMP/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/TommiGustafsson-HMP/subscriptions',
#      'organizations_url': 'https://api.github.com/users/TommiGustafsson-HMP/orgs',
#      'repos_url': 'https://api.github.com/users/TommiGustafsson-HMP/repos',
#      'events_url': 'https://api.github.com/users/TommiGustafsson-HMP/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/TommiGustafsson-HMP/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2019-12-14T12:56:29Z',
#     'updated_at': '2019-12-14T12:56:29Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'body': "Knight's starting abilities are quite low for a melee class. STR and CON could be a bit increased and his WIS decreased. Anyways, he does not start with any spells."}},
#   'public': True,
#   'created_at': '2019-12-14T12:56:30Z',
#   'org': {'id': 16661045,
#    'login': 'hyvanmielenpelit',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/hyvanmielenpelit',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16661045?'}}]

# %% [markdown]
# ## 其它用法

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get("http://httpbin.org/get", params=payload)
json.loads(r.text)
# Out:
# {'args': {'key1': 'value1', 'key2': 'value2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0'},
#  'origin': '159.117.78.4, 159.117.78.4',
#  'url': 'https://httpbin.org/get?key1=value1&key2=value2'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.19.1'},
#  'json': None,
#  'origin': '123.195.194.127, 123.195.194.127',
#  'url': 'https://httpbin.org/post'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests
import json
r = requests.get('https://api.github.com/events')
r.text
json.loads(r.text)
# Out:
# rs/pbober/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/relayr/erl-atom-utils/pulls/1/commits',
#     'review_comments_url': 'https://api.github.com/repos/relayr/erl-atom-utils/pulls/1/comments',
#     'review_comment_url': 'https://api.github.com/repos/relayr/erl-atom-utils/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/relayr/erl-atom-utils/issues/1/comments',
#     'statuses_url': 'https://api.github.com/repos/relayr/erl-atom-utils/statuses/1bfbae69e2fd75328dc1821938c2954b9b255abf',
#     'head': {'label': 'relayr:PDM-5774',
#      'ref': 'PDM-5774',
#      'sha': '1bfbae69e2fd75328dc1821938c2954b9b255abf',
#      'user': {'login': 'relayr',
#       'id': 5864098,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU4NjQwOTg=',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/5864098?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/relayr',
#       'html_url': 'https://github.com/relayr',
#       'followers_url': 'https://api.github.com/users/relayr/followers',
#       'following_url': 'https://api.github.com/users/relayr/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/relayr/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/relayr/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/relayr/subscriptions',
#       'organizations_url': 'https://api.github.com/users/relayr/orgs',
#       'repos_url': 'https://api.github.com/users/relayr/repos',
#       'events_url': 'https://api.github.com/users/relayr/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/relayr/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 133631135,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMzM2MzExMzU=',
#       'name': 'erl-atom-utils',
#       'full_name': 'relayr/erl-atom-utils',
#       'private': False,
#       'owner': {'login': 'relayr',
#        'id': 5864098,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU4NjQwOTg=',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/5864098?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/relayr',
#        'html_url': 'https://github.com/relayr',
#        'followers_url': 'https://api.github.com/users/relayr/followers',
#        'following_url': 'https://api.github.com/users/relayr/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/relayr/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/relayr/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/relayr/subscriptions',
#        'organizations_url': 'https://api.github.com/users/relayr/orgs',
#        'repos_url': 'https://api.github.com/users/relayr/repos',
#        'events_url': 'https://api.github.com/users/relayr/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/relayr/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/relayr/erl-atom-utils',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/relayr/erl-atom-utils',
#       'forks_url': 'https://api.github.com/repos/relayr/erl-atom-utils/forks',
#       'keys_url': 'https://api.github.com/repos/relayr/erl-atom-utils/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/relayr/erl-atom-utils/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/relayr/erl-atom-utils/teams',
#       'hooks_url': 'https://api.github.com/repos/relayr/erl-atom-utils/hooks',
#       'issue_events_url': 'https://api.github.com/repos/relayr/erl-atom-utils/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/relayr/erl-atom-utils/events',
#       'assignees_url': 'https://api.github.com/repos/relayr/erl-atom-utils/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/relayr/erl-atom-utils/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/relayr/erl-atom-utils/tags',
#       'blobs_url': 'https://api.github.com/repos/relayr/erl-atom-utils/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/relayr/erl-atom-utils/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/relayr/erl-atom-utils/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/relayr/erl-atom-utils/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/relayr/erl-atom-utils/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/relayr/erl-atom-utils/languages',
#       'stargazers_url': 'https://api.github.com/repos/relayr/erl-atom-utils/stargazers',
#       'contributors_url': 'https://api.github.com/repos/relayr/erl-atom-utils/contributors',
#       'subscribers_url': 'https://api.github.com/repos/relayr/erl-atom-utils/subscribers',
#       'subscription_url': 'https://api.github.com/repos/relayr/erl-atom-utils/subscription',
#       'commits_url': 'https://api.github.com/repos/relayr/erl-atom-utils/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/relayr/erl-atom-utils/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/relayr/erl-atom-utils/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/relayr/erl-atom-utils/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/relayr/erl-atom-utils/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/relayr/erl-atom-utils/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/relayr/erl-atom-utils/merges',
#       'archive_url': 'https://api.github.com/repos/relayr/erl-atom-utils/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/relayr/erl-atom-utils/downloads',
#       'issues_url': 'https://api.github.com/repos/relayr/erl-atom-utils/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/relayr/erl-atom-utils/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/relayr/erl-atom-utils/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/relayr/erl-atom-utils/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/relayr/erl-atom-utils/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/relayr/erl-atom-utils/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/relayr/erl-atom-utils/deployments',
#       'created_at': '2018-05-16T07:59:06Z',
#       'updated_at': '2019-02-18T16:03:33Z',
#       'pushed_at': '2019-12-14T12:57:03Z',
#       'git_url': 'git://github.com/relayr/erl-atom-utils.git',
#       'ssh_url': 'git@github.com:relayr/erl-atom-utils.git',
#       'clone_url': 'https://github.com/relayr/erl-atom-utils.git',
#       'svn_url': 'https://github.com/relayr/erl-atom-utils',
#       'homepage': None,
#       'size': 6,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Erlang',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'relayr:master',
#      'ref': 'master',
#      'sha': '5dfa1d2ef604882adc7bb9f6962c43180c9410c4',
#      'user': {'login': 'relayr',
#       'id': 5864098,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU4NjQwOTg=',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/5864098?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/relayr',
#       'html_url': 'https://github.com/relayr',
#       'followers_url': 'https://api.github.com/users/relayr/followers',
#       'following_url': 'https://api.github.com/users/relayr/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/relayr/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/relayr/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/relayr/subscriptions',
#       'organizations_url': 'https://api.github.com/users/relayr/orgs',
#       'repos_url': 'https://api.github.com/users/relayr/repos',
#       'events_url': 'https://api.github.com/users/relayr/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/relayr/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 133631135,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMzM2MzExMzU=',
#       'name': 'erl-atom-utils',
#       'full_name': 'relayr/erl-atom-utils',
#       'private': False,
#       'owner': {'login': 'relayr',
#        'id': 5864098,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU4NjQwOTg=',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/5864098?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/relayr',
#        'html_url': 'https://github.com/relayr',
#        'followers_url': 'https://api.github.com/users/relayr/followers',
#        'following_url': 'https://api.github.com/users/relayr/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/relayr/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/relayr/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/relayr/subscriptions',
#        'organizations_url': 'https://api.github.com/users/relayr/orgs',
#        'repos_url': 'https://api.github.com/users/relayr/repos',
#        'events_url': 'https://api.github.com/users/relayr/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/relayr/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/relayr/erl-atom-utils',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/relayr/erl-atom-utils',
#       'forks_url': 'https://api.github.com/repos/relayr/erl-atom-utils/forks',
#       'keys_url': 'https://api.github.com/repos/relayr/erl-atom-utils/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/relayr/erl-atom-utils/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/relayr/erl-atom-utils/teams',
#       'hooks_url': 'https://api.github.com/repos/relayr/erl-atom-utils/hooks',
#       'issue_events_url': 'https://api.github.com/repos/relayr/erl-atom-utils/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/relayr/erl-atom-utils/events',
#       'assignees_url': 'https://api.github.com/repos/relayr/erl-atom-utils/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/relayr/erl-atom-utils/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/relayr/erl-atom-utils/tags',
#       'blobs_url': 'https://api.github.com/repos/relayr/erl-atom-utils/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/relayr/erl-atom-utils/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/relayr/erl-atom-utils/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/relayr/erl-atom-utils/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/relayr/erl-atom-utils/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/relayr/erl-atom-utils/languages',
#       'stargazers_url': 'https://api.github.com/repos/relayr/erl-atom-utils/stargazers',
#       'contributors_url': 'https://api.github.com/repos/relayr/erl-atom-utils/contributors',
#       'subscribers_url': 'https://api.github.com/repos/relayr/erl-atom-utils/subscribers',
#       'subscription_url': 'https://api.github.com/repos/relayr/erl-atom-utils/subscription',
#       'commits_url': 'https://api.github.com/repos/relayr/erl-atom-utils/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/relayr/erl-atom-utils/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/relayr/erl-atom-utils/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/relayr/erl-atom-utils/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/relayr/erl-atom-utils/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/relayr/erl-atom-utils/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/relayr/erl-atom-utils/merges',
#       'archive_url': 'https://api.github.com/repos/relayr/erl-atom-utils/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/relayr/erl-atom-utils/downloads',
#       'issues_url': 'https://api.github.com/repos/relayr/erl-atom-utils/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/relayr/erl-atom-utils/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/relayr/erl-atom-utils/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/relayr/erl-atom-utils/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/relayr/erl-atom-utils/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/relayr/erl-atom-utils/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/relayr/erl-atom-utils/deployments',
#       'created_at': '2018-05-16T07:59:06Z',
#       'updated_at': '2019-02-18T16:03:33Z',
#       'pushed_at': '2019-12-14T12:57:03Z',
#       'git_url': 'git://github.com/relayr/erl-atom-utils.git',
#       'ssh_url': 'git@github.com:relayr/erl-atom-utils.git',
#       'clone_url': 'https://github.com/relayr/erl-atom-utils.git',
#       'svn_url': 'https://github.com/relayr/erl-atom-utils',
#       'homepage': None,
#       'size': 6,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Erlang',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/relayr/erl-atom-utils/pulls/1'},
#      'html': {'href': 'https://github.com/relayr/erl-atom-utils/pull/1'},
#      'issue': {'href': 'https://api.github.com/repos/relayr/erl-atom-utils/issues/1'},
#      'comments': {'href': 'https://api.github.com/repos/relayr/erl-atom-utils/issues/1/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/relayr/erl-atom-utils/pulls/1/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/relayr/erl-atom-utils/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/relayr/erl-atom-utils/pulls/1/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/relayr/erl-atom-utils/statuses/1bfbae69e2fd75328dc1821938c2954b9b255abf'}},
#     'author_association': 'MEMBER',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 27,
#     'deletions': 2,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2019-12-14T12:57:13Z',
#   'org': {'id': 5864098,
#    'login': 'relayr',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/relayr',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5864098?'}},
#  {'id': '11088664363',
#   'type': 'PushEvent',
#   'actor': {'id': 58868610,
#    'login': 'bekti-uciha',
#    'display_login': 'bekti-uciha',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bekti-uciha',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58868610?'},
#   'repo': {'id': 228016695,
#    'name': 'bekti-uciha/blog',
#    'url': 'https://api.github.com/repos/bekti-uciha/blog'},
#   'payload': {'push_id': 4396742947,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '6109cb3db6b13e7d2d3b784d7e23b7afa619e94b',
#    'before': '60fa36d56aa7c4677b844007567b7203a955ef0f',
#    'commits': [{'sha': '6109cb3db6b13e7d2d3b784d7e23b7afa619e94b',
#      'author': {'email': 'tasikmadu.tuban@gmail.com', 'name': 'bekti_uciha'},
#      'message': 'template',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/bekti-uciha/blog/commits/6109cb3db6b13e7d2d3b784d7e23b7afa619e94b'}]},
#   'public': True,
#   'created_at': '2019-12-14T12:57:13Z'},
#  {'id': '11088664366',
#   'type': 'CreateEvent',
#   'actor': {'id': 58561319,
#    'login': 'cjxd-bot-test',
#    'display_login': 'cjxd-bot-test',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cjxd-bot-test',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58561319?'},
#   'repo': {'id': 228019098,
#    'name': 'cb-kubecd/environment-pr-110-22-boot-gke-dev',
#    'url': 'https://api.github.com/repos/cb-kubecd/environment-pr-110-22-boot-gke-dev'},
#   'payload': {'ref': 'v0.0.2',
#    'ref_type': 'tag',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-14T12:57:13Z',
#   'org': {'id': 43623793,
#    'login': 'cb-kubecd',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/cb-kubecd',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43623793?'}},
#  {'id': '11088664359',
#   'type': 'PushEvent',
#   'actor': {'id': 57809473,
#    'login': 'bondarenkoant',
#    'display_login': 'bondarenkoant',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bondarenkoant',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57809473?'},
#   'repo': {'id': 221975819,
#    'name': 'bondarenkoant/bondarenkoant.github.io',
#    'url': 'https://api.github.com/repos/bondarenkoant/bondarenkoant.github.io'},
#   'payload': {'push_id': 4396742961,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '4edca1251667c6dde7753a90740d2153905e82cf',
#    'before': 'ba6005a9a9bed2e5b86634b2f8995e335d08d293',
#    'commits': [{'sha': '4edca1251667c6dde7753a90740d2153905e82cf',
#      'author': {'email': '57809473+bondarenkoant@users.noreply.github.com',
#       'name': 'bondarenkoant'},
#      'message': 'kinoMonster',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/bondarenkoant/bondarenkoant.github.io/commits/4edca1251667c6dde7753a90740d2153905e82cf'}]},
#   'public': True,
#   'created_at': '2019-12-14T12:57:13Z'},
#  {'id': '11088664358',
#   'type': 'WatchEvent',
#   'actor': {'id': 49980334,
#    'login': 'danffer2019',
#    'display_login': 'danffer2019',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/danffer2019',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49980334?'},
#   'repo': {'id': 133041229,
#    'name': 'madeas/box-shadows.css',
#    'url': 'https://api.github.com/repos/madeas/box-shadows.css'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-12-14T12:57:13Z'},
#  {'id': '11088664355',
#   'type': 'CreateEvent',
#   'actor': {'id': 16784797,
#    'login': 'antoniopegorelli',
#    'display_login': 'antoniopegorelli',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/antoniopegorelli',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16784797?'},
#   'repo': {'id': 228023188,
#    'name': 'antoniopegorelli/kmeans',
#    'url': 'https://api.github.com/repos/antoniopegorelli/kmeans'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-14T12:57:13Z'}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
import requests
import json
r = requests.get('https://cat-fact.herokuapp.com/facts')
json.loads(r.text)
# Out:
# lex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b1d40f1c57001592f12c',
#    'type': 'cat',
#    'text': "During the heat of the summer, set out an extra bowl of water and place ice cubes in it to keep it cold and refreshing. Cats love to lie on cool surfaces when it's hot—if you don't have an tile in your home, consider buying a few ceramic tiles from a home improvement store for your cat to rest on.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b2270f1c57001592f12d',
#    'type': 'cat',
#    'text': 'Among the British government officials who keep things running smoothly at 10 Downing Street is Larry, a cat that holds the distinguished position of Chief Mouser. Larry\'s duties, according to the U.K. government, include "greeting guests", "testing antique furniture for napping quality", and "contemplating a solution to the mouse occupancy of the house.".',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b2510f1c57001592f12e',
#    'type': 'cat',
#    'text': 'Courgars are the largest wild cats that can purr.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b27b0f1c57001592f12f',
#    'type': 'cat',
#    'text': 'The Norwegian Forest Cat is called "skogcatt" in its homeland of Norway and plays a role in the Norwegian fairy tales and legends.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b29f0f1c57001592f130',
#    'type': 'cat',
#    'text': 'The Abyssinian, the Siamese, and the American Shorthair were crossbred to produce the Ocicat breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b5b50f1c57001592f131',
#    'type': 'cat',
#    'text': 'Andy Warhol amassed quite the collection of feline friends during his lifetime, beginning with a Siamese cat named Hester that was given to him by actress Gloria Swanson. By breeding Hester with a cat named Sam, Warhol ended up with multiple litters of kittens, at one point housing 25 cats in his Upper East Side townhouse in NYC.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6090f1c57001592f132',
#    'type': 'cat',
#    'text': 'While two kittens might sound like double trouble, adopting two at a time can actually make your job easier. Two cans can keep each other company, reducing their need for socialization, and they will expend energy by playing together. Kittens in the same litter often form tight sibling bonds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6280f1c57001592f133',
#    'type': 'cat',
#    'text': 'Some animal shelters require kittens be adopted in pairs to ensure they came from the same litter.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b64e0f1c57001592f134',
#    'type': 'cat',
#    'text': 'The Havana Brown breed hails from England, where it was created by crossbreeding Siamese cats with domestic black cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b69a0f1c57001592f135',
#    'type': 'cat',
#    'text': "While we don't know the exact origins of the Russian Blue, it's commonly believed the breed comes from the Archangel Isles in northwestern Russia—the region's cold climate would certainly explain the breed's plush coat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6f10f1c57001592f136',
#    'type': 'cat',
#    'text': "Traveling with cats can be stressful for everyone involved. Whether you're taking a kitty to the vet, or on a road trip, or on a flight, there are things you can do to help her stay relaxed in the carrier. Pet shops sell calming treats and sprays that can reduce a cat's anxiety. It might also help to put a beloved toy or a blanket in the carrier.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b7170f1c57001592f137',
#    'type': 'cat',
#    'text': 'The wild-looking but domestic Ocicat is named for its resemblance to the ocelot, a small South American wild cat.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb910f1c57001592f14e',
#    'type': 'cat',
#    'text': 'Dr. Seuss wrote The Cat in the Hat using only 236 words.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d4a4fc6b6c1290015d43471',
#    'type': 'cat',
#    'text': 'Cats are the most interesting mammals on earth.',
#    'user': {'_id': '5d4a4fa4b6c1290015d43470',
#     'name': {'first': 'Yvette', 'last': 'Johnson-Rodgers'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d8a61992c54210015bf6076',
#    'type': 'cat',
#    'text': '"Cats "knead" because of seperation from their mothers".',
#    'user': {'_id': '5d70057df83a9d00155de899',
#     'name': {'first': 'Yang', 'last': 'Zhang'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9c556168a764001553b382',
#    'type': 'cat',
#    'text': 'A cat has 244 bones in its entire body—even more than a human, who only has 206 bones.',
#    'user': {'_id': '5d84ce8abf541a0015b5febb',
#     'name': {'first': 'Veronika', 'last': 'Koval'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9d4ae168a764001553b388',
#    'type': 'cat',
#    'text': 'Cats conserve energy by sleeping for an average of 13 to14 hours a day.',
#    'user': {'_id': '5d9d4a4468a764001553b387',
#     'name': {'first': 'Erick', 'last': 'Vazquez'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5db2bd49085bcb0015750662',
#    'type': 'cat',
#    'text': 'All cats are grey at night.',
#    'user': {'_id': '5db2bcbe085bcb0015750661',
#     'name': {'first': 'Владимир', 'last': 'А'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5dc944f5353d620015a71ce0',
#    'type': 'cat',
#    'text': "I got 3 cat and i'm allergic to them.",
#    'user': {'_id': '5dc944d7353d620015a71cdf',
#     'name': {'first': 'João', 'last': 'Guerreiro'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9cf25868a764001553b386',
#    'type': 'cat',
#    'text': 'XYZ.',
#    'user': {'_id': '5d9cf24e68a764001553b385',
#     'name': {'first': 'Mateusz', 'last': 'Głowacki'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daee7dbec4a6500156d2e6d',
#    'type': 'cat',
#    'text': 'Test.',
#    'user': {'_id': '5da41b7504ce7e001534bfa1',
#     'name': {'first': 'mohammed', 'last': 'aljundi'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38baf20f1c57001592f14b',
#    'type': 'cat',
#    'text': "The stationmaster of the Kishi rail station in western Japan until 2015 was a cat named Tama. The calico cat wore a stationmaster's cap and greeted visitors by the ticket gate. After her death, Tama was elevated to the status of a goddess in a Shinto-style funeral.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb440f1c57001592f14c',
#    'type': 'cat',
#    'text': "It's important for cats to have regular ear exams—this is something you can do at home! Gently fold back the ears and look into the ear canal. The inner ear should be pale pink with little to no earwax. If you notice redness, swelling, discharge, or a lot of earwax, it's time to see a veterinarian.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb7a0f1c57001592f14d',
#    'type': 'cat',
#    'text': 'In Norse mythology, the goddess Freya travels in a chariot pulled by two cats—specifically Norwegian Forest Cats.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bbb20f1c57001592f14f',
#    'type': 'cat',
#    'text': 'American Curl kittens are born with straight ears, but the ears begin to curl back after just a few days.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc0c0f1c57001592f150',
#    'type': 'cat',
#    'text': "If your cat licks from the toilet, bathtub, or sink, she may be telling you something about the water bowl. Make sure it's clean, replace the water regularly to keep it from getting stale or developing a film on top, and if necessary, get a new bowl. Some cats prefer glass bowls to plastic.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc630f1c57001592f151',
#    'type': 'cat',
#    'text': "Georgia O'Keeffe was a celebrated painter, a figurehead of American modernism, a fashion icon, and... a cat owner! O'Keeffe kept a number of animals at her home in New Mexico, including her pet Siamese cat, who appears alongside O'Keeffe in a portrait shot by photographer John Candelario.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc970f1c57001592f152',
#    'type': 'cat',
#    'text': 'The pink substance inside a cat\'s nail is called the "quick" or the "dermis". When trimming your cat\'s nails, be sure to only cut the upper white part of the nail, not the quick.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bcc00f1c57001592f153',
#    'type': 'cat',
#    'text': 'The irresistable and cuddly Ragamuffin is the result of crossbreeding Ragdoll cats with Persians, Himalayans, and other larger longhaired breeds.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd180f1c57001592f154',
#    'type': 'cat',
#    'text': 'Cats are among only a few animals that walk by moving their two right legs one after another and then their two left legs, rather than moving diagonal limbs simultaneously. Giraffes and camels also have this quality.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd750f1c57001592f155',
#    'type': 'cat',
#    'text': "Legend holds that a goddess rewarded a temple cat's piety by turning the cat's eyes blue and his coat golden, thus creating the first Birman cat.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bdab0f1c57001592f156',
#    'type': 'cat',
#    'text': "While some cats love being brushed, others don't take to it naturally. Try to groom your cat in the same spot at the same time of day to create a sense of routine.",
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be200f1c57001592f157',
#    'type': 'cat',
#    'text': 'The Turkish Van is often called the "swimming cat" because they are naturals in the water, thanks in part to their uniquely textured, water-resistant coat.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be370f1c57001592f158',
#    'type': 'cat',
#    'text': 'Kittens typically begin to engage in playful behavior at around four weeks of age.',
#    'user': {'_id': '5a8b1dce4709d90020cb1285',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d3e2191484b54001508b0df',
#    'type': 'cat',
#    'text': 'Cats can be nation president.',
#    'user': {'_id': '5d3dedfa484b54001508b0de',
#     'name': {'first': 'Jonathan', 'last': 'Velazquez'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d4878cca994550015e6ca0a',
#    'type': 'cat',
#    'text': 'Horse.',
#    'user': {'_id': '5d48783ca994550015e6ca09',
#     'name': {'first': 'Artemiy', 'last': 'Pyatakov'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d5dc687b155490015c5663f',
#    'type': 'cat',
#    'text': 'The cats are fools.',
#    'user': {'_id': '5d5dc631b155490015c5663e',
#     'name': {'first': 'Martin', 'last': 'Paredez'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d736a9617cd6300154df550',
#    'type': 'cat',
#    'text': 'A.',
#    'user': {'_id': '5d736a7817cd6300154df54f',
#     'name': {'first': 'Ade', 'last': 'Suluh'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d839adc8a86520015f44f8e',
#    'type': 'cat',
#    'text': 'Cats purr.',
#    'user': {'_id': '5d839a818a86520015f44f8d',
#     'name': {'first': 'Ju', 'last': 'Lia'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d91fc7cc586ca0015c71695',
#    'type': 'cat',
#    'text': 'GG.',
#    'user': {'_id': '5d91fc56c586ca0015c71694',
#     'name': {'first': '기웅', 'last': '김'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d94d26c6845b800156579b5',
#    'type': 'cat',
#    'text': 'Gatos.',
#    'user': {'_id': '5d94d25c6845b800156579b4',
#     'name': {'first': 'Dave', 'last': 'More'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d9bd688f98b610015c25ee2',
#    'type': 'cat',
#    'text': 'Is this a dumb app?.',
#    'user': {'_id': '5d9bd5b9f98b610015c25edf',
#     'name': {'first': 'Digggid', 'last': 'Tsar'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daa121c79186100154250be',
#    'type': 'cat',
#    'text': 'Dr. Bootsy Calico love cats, he was raised by cats. He is the main antagonist in The Boss Baby: Back in Business.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daa192179186100154250c4',
#    'type': 'cat',
#    'text': 'GitHub is a cloud source version control system where its mascot is an octocat, an anthropomorphized cat with five tentacles.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5daed556ec4a6500156d2e6c',
#    'type': 'cat',
#    'text': 'One of the biggest pilgrimage sites in the middle ages was the cathedral of Caterbury.',
#    'user': {'_id': '5daec340ec4a6500156d2e6b',
#     'name': {'first': 'jo', 'last': 'ne'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db6ac1ab5f3720015400ea4',
#    'type': 'cat',
#    'text': 'Cats have fur.',
#    'user': {'_id': '5db6ac04b5f3720015400ea3',
#     'name': {'first': 'Deekay', 'last': 'Em'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db9577511880200157ad78a',
#    'type': 'cat',
#    'text': 'Testing bro.',
#    'user': {'_id': '5db956e711880200157ad783',
#     'name': {'first': 'Test', 'last': 'test'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5db9bf3511880200157ad78e',
#    'type': 'cat',
#    'text': 'A cat has been known to beg for food even when there already is food in its bowl.',
#    'user': {'_id': '5db9beb211880200157ad78d',
#     'name': {'first': 'Nick', 'last': 'Hyland'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd21b91a960ba0015a66895',
#    'type': 'cat',
#    'text': 'The technical term for a cat’s hairball is a “bezoar.”.',
#    'user': {'_id': '5dd21b29a960ba0015a66894',
#     'name': {'first': 'Gabriel', 'last': 'Lien'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd3a48821bcaf0015eaa854',
#    'type': 'cat',
#    'text': 'Cats named Meowduri are cute.',
#    'user': {'_id': '5dd3a45921bcaf0015eaa851',
#     'name': {'first': 'Aaqib', 'last': 'Ismail'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5dd401d08f1fb70015b894ad',
#    'type': 'cat',
#    'text': "Cat's are not dogs.",
#    'user': {'_id': '5dd401b88f1fb70015b894ac',
#     'name': {'first': 'Ronnie', 'last': 'Kilsbo'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ddd252f3e2c6c0015051ac2',
#    'type': 'cat',
#    'text': 'That cat can be the killer of mom.',
#    'user': {'_id': '5ddd14d23e2c6c0015051ac1',
#     'name': {'first': 'FATİH', 'last': 'KESER'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de0a5d32abaa900154956c9',
#    'type': 'cat',
#    'text': 'This is the first time.',
#    'user': {'_id': '5de0a5b02abaa900154956c8',
#     'name': {'first': 'Sushen', 'last': 'Biswas'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de608922c455b00153df05d',
#    'type': 'cat',
#    'text': 'Coba cat nyata.',
#    'user': {'_id': '5dac75c56ba4f80015053523',
#     'name': {'first': 'Danang', 'last': 'Setyawan'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de6090e2c455b00153df05e',
#    'type': 'cat',
#    'text': 'Cats has no hands.',
#    'user': {'_id': '5dac75c56ba4f80015053523',
#     'name': {'first': 'Danang', 'last': 'Setyawan'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de609812c455b00153df05f',
#    'type': 'cat',
#    'text': 'Testing aja.',
#    'user': {'_id': '5dac75c56ba4f80015053523',
#     'name': {'first': 'Danang', 'last': 'Setyawan'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de780600013130015a3ccaf',
#    'type': 'cat',
#    'text': 'More than half of the world’s felines don’t respond to catnip.',
#    'user': {'_id': '5de681752c455b00153df068',
#     'name': {'first': 'Leonard', 'last': 'Wohlfarth'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de7808a0013130015a3ccb0',
#    'type': 'cat',
#    'text': 'The wealthiest cat in the world is named Blackie.',
#    'user': {'_id': '5de681752c455b00153df068',
#     'name': {'first': 'Leonard', 'last': 'Wohlfarth'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de780a00013130015a3ccb1',
#    'type': 'cat',
#    'text': 'A group of kittens is called a Kindle.',
#    'user': {'_id': '5de681752c455b00153df068',
#     'name': {'first': 'Leonard', 'last': 'Wohlfarth'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de780d30013130015a3ccb2',
#    'type': 'cat',
#    'text': 'In October 1983, a cat named "Félicette" became the first cat in space.',
#    'user': {'_id': '5de681752c455b00153df068',
#     'name': {'first': 'Leonard', 'last': 'Wohlfarth'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5de780e60013130015a3ccb3',
#    'type': 'cat',
#    'text': 'Cats can be allergic to humans.',
#    'user': {'_id': '5de681752c455b00153df068',
#     'name': {'first': 'Leonard', 'last': 'Wohlfarth'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5deb725edeb28e00158cd804',
#    'type': 'cat',
#    'text': 'Cats are nuts.',
#    'user': {'_id': '5deb723adeb28e00158cd803',
#     'name': {'first': 'Trip Store', 'last': 'Krabi'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5df01498e87f9d00157245af',
#    'type': 'cat',
#    'text': 'Cats has 7 souls.',
#    'user': {'_id': '5df0128be87f9d00157245ad',
#     'name': {'first': 'sagiv', 'last': 'netanel'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5df1f127cf9b010015052b7d',
#    'type': 'cat',
#    'text': 'Arfa.saif92@gmail.com.',
#    'user': {'_id': '5df1f0f4cf9b010015052b7c',
#     'name': {'first': 'Muhammad', 'last': 'Ehsan'}},
#    'upvotes': 0,
#    'userUpvoted': None}]}

# %% [markdown]
# # 反爬：登入授權模擬
#
# * 了解「登入權限機制」的反爬蟲機制
# * 「登入權限機制」反爬蟲的因應策略

# %% [markdown]
# ## 未授權前存取

# %%
import requests
from bs4 import BeautifulSoup

# %%
res = requests.get('https://www.ptt.cc/bbs/Gossiping/index.html', verify = False)
soup = BeautifulSoup(res.text, 'html.parser')
print(soup.text)
# Out:
# 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 本網站已依網站內容分級規定處理
# 警告︰您即將進入之看板內容需滿十八歲方可瀏覽。
# 若您尚未年滿十八歲，請點選離開。若您已滿十八歲，亦不可將本區之內容派發、傳閱、出售、出租、交給或借予年齡未滿18歲的人士瀏覽，或將本網站內容向該人士出示、播放或放映。
#
#
#
#
#
#
# 我同意，我已年滿十八歲進入
#
#
# 未滿十八歲或不同意本條款離開
#
#
#
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
#
#
#
#
#
#
# C:\Users\Username\AppData\Local\Programs\Python\Python37\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# C:\Users\Username\AppData\Local\Programs\Python\Python37\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,

# %% [markdown]
# ## 模仿授權機制

# %% [markdown]
# ### 方法一：先送登入，再送請求

# %%
rs = requests.session()
payload={
    'from':'/bbs/Gossiping/index.html',
    'yes': 'yes'
}
res = rs.post('https://www.ptt.cc/ask/over18',verify = False, data = payload)
res = rs.get('https://www.ptt.cc/bbs/Gossiping/index.html',verify = False)
soup = BeautifulSoup(res.text,'html.parser')
print(soup.text)
# Out:
# 看板 Gossiping 文章列表 - 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 批踢踢實業坊
# ›
# 看板 Gossiping
# 關於我們
# 聯絡資訊
#
#
#
#
#
#
# 看板
# 精華區
#
#
# 最舊
# ‹ 上頁
# 下頁 ›
# 最新
#
#
#
#
#
#
#
#
#
#
# 1
#
# Re: [問卦] 林OO娥是不是很婆?
#
#
# CavendishJr
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 CavendishJr 的文章
#
#
#  2/12
#
#
#
#
# 8
#
# [問卦] 館長的健身房淋浴間超大間是什麼用意
#
#
# rick102233
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 rick102233 的文章
#
#
#  2/12
#
#
#
#
#
#
# Re: [問卦] 聖經對女兒把爸爸搖出來的看法是？
#
#
# justice00s
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 justice00s 的文章
#
#
#  2/12
#
#
#
#
#
#
# Re: [問卦] 蟑螂484就是當年的覺青?
#
#
# uhbygv45
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 uhbygv45 的文章
#
#
#  2/12
#
#
#
#
# 3
#
# [問卦] 今天男孩要赴女孩最後的約!
#
#
# gn01765288
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 gn01765288 的文章
#
#
#  2/12
#
#
#
#
# 1
#
# [問卦] 新冠市在哪？
#
#
# Miralles
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Miralles 的文章
#
#
#  2/12
#
#
#
#
# 6
#
# [問卦] 可樂跟雪碧哪個才是真 肥宅快樂水
#
#
# stuj9019
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 stuj9019 的文章
#
#
#  2/12
#
#
#
#
# 2
#
# Re: [新聞] 多位立委陳情案釀陸委會暴衝　蔡英文拉回
#
#
# FlashMan
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 FlashMan 的文章
#
#
#  2/12
#
#
#
#
# 1
#
# [新聞] 甜美女星浜辺美波送手作巧克力 佐佐木朗希
#
#
# emperor
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 emperor 的文章
#
#
#  2/12
#
#
#
#
#
#
# [問卦] 課本為什麼對漢武帝著墨很多而非宣帝
#
#
# paralux
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 paralux 的文章
#
#
#  2/12
#
#
#
#
#
#
# Re: [新聞] 陸配子女入境喊卡　網友湧蔡英文臉書：慶
#
#
# Beanoodle
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Beanoodle 的文章
#
#
#  2/12
#
#
#
#
#
# 5
#
# [公告] 關於板上疫情相關問卦&八卦板板規
#
#
# arsonlolita
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 arsonlolita 的文章
#
#
#  1/31
# M
#
#
#
# 20
#
# [徵求]行車紀錄器1/29 北市大安區 晚上10點多
#
#
# skywgu
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 skywgu 的文章
#
#
#  1/31
#
#
#
#
# X2
#
# [公告] 武漢肺炎討論專區&二月份置底閒聊文
#
#
# Bignana
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Bignana 的文章
#
#
#  2/03
# M
#
#
#
# 18
#
# [公告] ★八卦板主投票開始了★
#
#
# arsonlolita
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 arsonlolita 的文章
#
#
#  2/12
#
#
#
#
#
#
# ［徵求］ 行車記錄器 國道北上17.7K 晚上18:3
#
#
# berger200350
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 berger200350 的文章
#
#
#  2/12
#
#
#
#
# 本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。
#
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
#
#
#
#
#
#
# C:\Users\Username\AppData\Local\Programs\Python\Python37\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# C:\Users\Username\AppData\Local\Programs\Python\Python37\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# C:\Users\Username\AppData\Local\Programs\Python\Python37\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,

# %% [markdown]
# ### 方法二：在請求中帶入 cookie

# %%
res = requests.get('https://www.ptt.cc/bbs/Gossiping/index.html',verify = False, cookies={'over18': '1'})
soup = BeautifulSoup(res.text,'html.parser')
print(soup.text)
# Out:
# 看板 Gossiping 文章列表 - 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 批踢踢實業坊
# ›
# 看板 Gossiping
# 關於我們
# 聯絡資訊
#
#
#
#
#
#
# 看板
# 精華區
#
#
# 最舊
# ‹ 上頁
# 下頁 ›
# 最新
#
#
#
#
#
#
#
#
#
#
# 2
#
# Re: [新聞]「台灣野人」恆春半島吃不停 林管處盼吸收
#
#
# hltinokuo
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 hltinokuo 的文章
#
#
#  7/29
#
#
#
#
# 3
#
# [問卦] 香港運輸物資居然用大隊接力！
#
#
# charco
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 charco 的文章
#
#
#  7/29
#
#
#
#
# 7
#
# [問卦] 有人會直接吃鮪魚罐頭嗎
#
#
# Antihuman
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Antihuman 的文章
#
#
#  7/29
#
#
#
#
#
#
# [問卦] 海底撈點這樣算摳嗎？
#
#
# danmitsu
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 danmitsu 的文章
#
#
#  7/29
#
#
#
#
#
#
# [問卦] 為什麼台灣找不到混血黑人球員??
#
#
# kerkerson
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 kerkerson 的文章
#
#
#  7/29
#
#
#
#
# 1
#
# [問卦] 不會念書的人有女友嗎？
#
#
# Francise
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Francise 的文章
#
#
#  7/29
#
#
#
#
#
#
# [新聞] IZ*ONE熱潮狂掃《TGC 富山 2019》 八千人
#
#
# ATCTaiwan
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 ATCTaiwan 的文章
#
#
#  7/29
#
#
#
#
# 2
#
# Re: [新聞] 回應韓國瑜 蔡英文：守護中華民國我說到
#
#
# cowardlyman
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 cowardlyman 的文章
#
#
#  7/29
#
#
#
#
# 2
#
# [問卦] 農藥店真的很賺嗎？
#
#
# brucielu95
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 brucielu95 的文章
#
#
#  7/29
#
#
#
#
# 1
#
# [問卦] STU瀧野由美子終究只是個第三者嗎?
#
#
# emperor
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 emperor 的文章
#
#
#  7/29
#
#
#
#
#
#
# Re: [問卦] 買私菸的官員會不會變成世紀罪人？
#
#
# fuxdk
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 fuxdk 的文章
#
#
#  7/29
#
#
#
#
# 6
#
# Re: [問卦] 俄羅斯小蘿莉在跳什麼舞？
#
#
# violinlife
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 violinlife 的文章
#
#
#  7/29
#
#
#
#
#
#
# [問卦] 洗完雞雞容易激起性慾嗎
#
#
# dinex
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 dinex 的文章
#
#
#  7/29
#
#
#
#
# 4
#
# [問卦] 為什麼教科書都要寫「偽」滿洲國？
#
#
# leopika
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 leopika 的文章
#
#
#  7/29
#
#
#
#
#
#
# [問卦] 假日時光倒流，想回去什麼時候
#
#
# blackzero1
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 blackzero1 的文章
#
#
#  7/29
#
#
#
#
#
#
# [問卦] 台鐵補票事件是不是顯露部分台灣人醜陋?
#
#
# MizunaRei
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 MizunaRei 的文章
#
#
#  7/29
#
#
#
#
#
#
#
# [公告] 八卦板板規(2019.07.21)
#
#
# Bignana
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Bignana 的文章
#
#
#  7/21
# !
#
#
#
# 63
#
# [問卦]懇求7/19大溪往三峽路段死亡車禍行車紀錄
#
#
# nekosandy
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 nekosandy 的文章
#
#
#  7/21
# M
#
#
#
# 19
#
# [公告] 版規4-16修正草案
#
#
# arsonlolita
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 arsonlolita 的文章
#
#
#  7/23
# M
#
#
#
# 87
#
# [尋人]尋人啟事 懇請幫忙
#
#
# skysea0940
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 skysea0940 的文章
#
#
#  7/26
#
#
#
#
# 39
#
# [公告] 七月份置底閒聊文
#
#
# Bignana
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Bignana 的文章
#
#
#  7/01
# M
#
#
#
# 本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。
#
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# /Users/wei/.virtualenvs/py3/lib/python3.6/site-packages/urllib3/connectionpool.py:857: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %% [markdown]
# ## 作業目標
#
# * 找一個需要登入的網站試試看，並說明思考流程
# （如果不知道要用哪個網站的話，可以試試看 https://github.com/new 網址，未登入時會被導向登入頁）

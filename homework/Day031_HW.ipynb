# %% [markdown]
# # 反爬：瀏覽器標頭與基本資訊
#
#
# * 了解「檢查 HTTP 標頭檔」的反爬蟲機制
# * 「檢查 HTTP 標頭檔」反爬蟲的因應策略

# %% [markdown]
# ## 作業目標
#
# * 尋找一個網站是有作 Header 檢查的（Hint: 有加跟沒有加回傳結果不一樣）
# * 用上述網站說明該如何判斷 Header 中必須加上哪些資料才會正確

# %% [markdown]
# ### 尋找一個網站是有作 Header 檢查的（Hint: 有加跟沒有加回傳結果不一樣）

# %%
import requests
url='https://www.zhihu.com/explore'
r=requests.get(url)
print(r.text)
# Out:
# '<html>\r\n<head><title>400 Bad Request</title></head>\r\n<body bgcolor="white">\r\n<center><h1>400 Bad Request</h1></center>\r\n<hr><center>openresty</center>\r\n</body>\r\n</html>\r\n'

# %% [markdown]
# ### 用上述網站說明該如何判斷 Header 中必須加上哪些資料才會正確

# %%
import requests
url='https://www.zhihu.com/explore'
header={'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36'}
r=requests.get(url,headers=header)
print(r.text)
# Out:
# pg","endAt":1581998400,"url":"\u002Froundtables\u002Fexplore\u002Fcards\u002Froundtable\u002Fqinzishiguang","followersCount":107,"intro":"宅家不出门，面对孩子这个活力满满的「发动机」，作为家长，该如何与孩子共同度过这段难得的宅在家中的亲子时光？本期圆桌，父母世界将与你一起探索，如何宅在家高质量陪伴。","isFollowing":false,"guests":[{"avatarUrl":"https:\u002F\u002Fpic4.zhimg.com\u002F50\u002Fv2-547d9fa66696d690d8f07ab070fc8c2e_hd.jpg"},{"avatarUrl":"https:\u002F\u002Fpic1.zhimg.com\u002F50\u002Fv2-99d33b660306b5b1aba9ceb1a4a3f7b5_hd.jpg"},{"avatarUrl":"https:\u002F\u002Fpic2.zhimg.com\u002F50\u002Fv2-3a2f23c1cb182f5f055a1e02d6e97257_hd.jpg"},{"avatarUrl":"https:\u002F\u002Fpic4.zhimg.com\u002F50\u002Fv2-669b870904db812dfb623b715921886e_hd.jpg"},{"avatarUrl":"https:\u002F\u002Fpic2.zhimg.com\u002F50\u002Fv2-b2d2e506315b334e935773c639f68eb7_hd.jpg"},{"avatarUrl":"https:\u002F\u002Fpic1.zhimg.com\u002F50\u002Fv2-aec1173221590800b8fd28d5da8ddae0_hd.jpg"},{"avatarUrl":"https:\u002F\u002Fpic2.zhimg.com\u002F50\u002Fv2-ebfabe1579bb1601bb944617255a6dc9_hd.jpg"},{"avatarUrl":"https:\u002F\u002Fpic3.zhimg.com\u002F50\u002Fv2-3b4832d2bf842861cae0f6e427aee758_hd.jpg"},{"avatarUrl":"https:\u002F\u002Fpic2.zhimg.com\u002F50\u002Fv2-18fc85cf1aae5679de51d42c4589384e_hd.jpg"},{"avatarUrl":"https:\u002F\u002Fpic3.zhimg.com\u002F50\u002Fv2-cd7054e35870176e384288f6d5caed74_hd.jpg"},{"avatarUrl":"https:\u002F\u002Fpic2.zhimg.com\u002F50\u002Fv2-fddbd05c0251ab579c1aba41327440fe_hd.jpg"},{"avatarUrl":"https:\u002F\u002Fpic4.zhimg.com\u002F50\u002Fv2-47b787d2f1262c34155e1a0418ffa243_hd.jpg"}],"questions":[{"followerCount":50,"title":"3岁以下婴幼儿早教机构、亲子园暂停线下培训，在家给如何给孩子做早教？","url":"https:\u002F\u002Fwww.zhihu.com\u002Fquestion\u002F368481456","type":"question","id":368481456,"answerCount":11},{"followerCount":404,"title":"春节在家，可以怎么陪孩子玩？有哪些有意思的亲子互动？","url":"https:\u002F\u002Fwww.zhihu.com\u002Fquestion\u002F367797243","type":"question","id":367797243,"answerCount":77},{"followerCount":3928,"title":"有没有适合在家玩的亲子游戏啊？","url":"https:\u002F\u002Fwww.zhihu.com\u002Fquestion\u002F33190082","type":"question","id":33190082,"answerCount":94}],"logo":"https:\u002F\u002Fpic3.zhimg.com\u002F50\u002Fv2-a07383ece9dfdeacdf2ff12336819831_hd.jpg","urlToken":"qinzishiguang"}},"order":["binfenqianduan","zhai2020","valentinesday09","qinzishiguang"]},"collections":{"27630611":{"favitems":[{"content":{"isCollapsed":false,"author":{"avatarUrlTemplate":"https:\u002F\u002Fpic4.zhimg.com\u002Fda8e974dc_{size}.jpg","name":"知乎用户","headline":"","gender":1,"userType":"people","urlToken":"","isAdvertiser":false,"avatarUrl":"https:\u002F\u002Fpic4.zhimg.com\u002Fda8e974dc_is.jpg","isOrg":false,"type":"people","url":"http:\u002F\u002Fwww.zhihu.com\u002Fapi\u002Fv4\u002Fpeople\u002F0","badge":[],"id":"3d8bf515335eb11d3d847d6182cbf98e"},"url":"http:\u002F\u002Fwww.zhihu.com\u002Fapi\u002Fv4\u002Fanswers\u002F1005518859","question":{"questionType":"normal","title":"有编制真的很重要么？","url":"http:\u002F\u002Fwww.zhihu.com\u002Fapi\u002Fv4\u002Fquestions\u002F353883119","created":1572759578,"type":"question","id":353883119,"updatedTime":1572759578},"id":1005518859,"excerpt":"编制是对抗马太效应的有效武器，是基层维持稳定的基础，也是底层群众的最佳选择。我们以公医师三大编制群体为例。赵警官，钱大夫，孙老师通过各自的努力成为各自领域的佼佼者，可谓年轻有为。如果取消编制呢？赵警官年富力强有能力，开了私人安保公司，组织…","updatedTime":1581169597,"commentCount":159,"extras":"","answerType":"answer","createdTime":1581169463,"isCopyable":false,"type":"answer","thumbnail":"","voteupCount":1327}},{"content":{"isCollapsed":false,"author":{"avatarUrlTemplate":"https:\u002F\u002Fpic1.zhimg.com\u002F8895d5d7a_{size}.jpg","name":"三种不同的红色","headline":"听老婆话。跟党走。","gender":1,"userType":"people","urlToken":"san-chong-bu-tong-de-hong-se","isAdvertiser":false,"avatarUrl":"https:\u002F\u002Fpic1.zhimg.com\u002F8895d5d7a_is.jpg","isOrg":false,"type":"people","url":"http:\u002F\u002Fwww.zhihu.com\u002Fapi\u002Fv4\u002Fpeople\u002Ff5d6726e49d4451d707e84b554adf8c6","badge":[],"id":"f5d6726e49d4451d707e84b554adf8c6"},"url":"http:\u002F\u002Fwww.zhihu.com\u002Fapi\u002Fv4\u002Fanswers\u002F1005781874","question":{"questionType":"norma ...
